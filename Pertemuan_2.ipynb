# %% [markdown]
# <a href="https://colab.research.google.com/github/intandwinancy25/Pemrograman-Dasar-2/blob/main/Pertemuan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jawaban Latihan 1

tegangan_panel = 18
arus_panel = 6
jenis_sel = "Monocrystalline"

print(tegangan_panel)
print(arus_panel)
print(jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
# Jawaban Latihan 2

jumlah_resistor = 10
tegangan_baterai = 12.5
saklar_aktif = True
nama_komponen = "Resistor"

print(jumlah_resistor)
print(type(jumlah_resistor))

print(tegangan_baterai)
print(type(tegangan_baterai))

print(saklar_aktif)
print(type(saklar_aktif))

print(nama_komponen)
print(type(nama_komponen))
# Out:
# 10
# <class 'int'>
# 12.5
# <class 'float'>
# True
# <class 'bool'>
# Resistor
# <class 'str'>

# %%
# Jawaban Latihan 3

nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluaran, type(tegangan_keluaran))
print(sedang_beroperasi, type(sedang_beroperasi))
# Out:
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
# Jawaban Latihan 4

tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

# (a) Mencetak pembacaan pertama dan terakhir
print("Pembacaan pertama:", tegangan_harian[0])
print("Pembacaan terakhir:", tegangan_harian[-1])

# (b) Menambahkan pembacaan baru
tegangan_harian.append(222.0)

# (c) Mencetak jumlah total data
print("Jumlah total data:", len(tegangan_harian))
# Out:
# Pembacaan pertama: 217.5
# Pembacaan terakhir: 216.9
# Jumlah total data: 7

# %%
# Jawaban Latihan 5

motor_listrik = {
    "nama": "Motor Induksi",
    "daya_kW": 5.5,
    "tegangan_V": 380,
    "rpm": 1500
}

# Mencetak salah satu nilai melalui key
print(motor_listrik["nama"])

# Mengubah nilai rpm
motor_listrik["rpm"] = 1450

# Mencetak seluruh dictionary
print(motor_listrik)
# Out:
# Motor Induksi
# {'nama': 'Motor Induksi', 'daya_kW': 5.5, 'tegangan_V': 380, 'rpm': 1450}

# %%
# Jawaban Latihan 6

pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80, "status": "pemeliharaan"},
]

# Mencetak nama unit kedua
print(pembangkit[1]["nama"])

# Mengubah status salah satu unit
pembangkit[2]["status"] = "operasi"

# Menambahkan satu unit baru
pembangkit.append({
    "nama": "Unit-4",
    "kapasitas_MW": 120,
    "status": "operasi"
})

# Mencetak seluruh data
print(pembangkit)
# Out:
# Unit-2
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'operasi'}, {'nama': 'Unit-4', 'kapasitas_MW': 120, 'status': 'operasi'}]
